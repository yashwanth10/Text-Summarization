# %%
# !pip install inltk
# Out:
# Collecting inltk
#   Downloading inltk-0.9-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp>=3.5.4 in /opt/conda/lib/python3.10/site-packages (from inltk) (3.9.1)
# Requirement already satisfied: async-timeout>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from inltk) (4.0.3)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from inltk) (9.5.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from inltk) (4.12.2)
# Collecting bottleneck (from inltk)
#   Downloading Bottleneck-1.3.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: fastprogress>=0.1.19 in /opt/conda/lib/python3.10/site-packages (from inltk) (1.0.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from inltk) (3.7.5)
# Requirement already satisfied: numexpr in /opt/conda/lib/python3.10/site-packages (from inltk) (2.10.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.10/site-packages (from inltk) (1.26.4)
# Collecting nvidia-ml-py3 (from inltk)
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from inltk) (21.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from inltk) (2.1.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from inltk) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from inltk) (2.31.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from inltk) (1.11.4)
# Requirement already satisfied: spacy>=2.0.18 in /opt/conda/lib/python3.10/site-packages (from inltk) (3.7.2)
# Collecting typing (from inltk)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fastai==1.0.57 (from inltk)
#   Downloading fastai-1.0.57-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from inltk) (0.2.0)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from fastai==1.0.57->inltk) (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from fastai==1.0.57->inltk) (0.16.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.5.4->inltk) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.5.4->inltk) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.5.4->inltk) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.5.4->inltk) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.5.4->inltk) (1.3.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (4.66.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (2.5.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (69.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=2.0.18->inltk) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->inltk) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->inltk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->inltk) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->inltk) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->inltk) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->inltk) (2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->inltk) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->inltk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->inltk) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->inltk) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->inltk) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->inltk) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->inltk) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->inltk) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->inltk) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->inltk) (4.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->inltk) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.0.18->inltk) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.0.18->inltk) (0.1.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (3.2.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (2024.2.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy>=2.0.18->inltk) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.0.18->inltk) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy>=2.0.18->inltk) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.0.0->fastai==1.0.57->inltk) (1.3.0)
# Downloading inltk-0.9-py3-none-any.whl (13 kB)
# Downloading fastai-1.0.57-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 11.5 MB/s eta 0:00:00
# Downloading Bottleneck-1.3.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.1/354.1 kB 18.8 MB/s eta 0:00:00
# Building wheels for collected packages: nvidia-ml-py3, typing
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19171 sha256=08e017745d99f2284b8a7b24ff830a9e2ae330093a417644f9ff8e01c7a409fd
#   Stored in directory: /root/.cache/pip/wheels/5c/d8/c0/46899f8be7a75a2ffd197a23c8797700ea858b9b34819fbf9e
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26304 sha256=80f02e583806406bec0aa665f3101d400981774f5abeb4896490d423e8474238
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built nvidia-ml-py3 typing
# Installing collected packages: nvidia-ml-py3, typing, bottleneck, fastai, inltk
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.7.14
#     Uninstalling fastai-2.7.14:
#       Successfully uninstalled fastai-2.7.14
# Successfully installed bottleneck-1.3.8 fastai-1.0.57 inltk-0.9 nvidia-ml-py3-7.352.0 typing-3.7.4.3

# %%
pip install --upgrade pandas numpy matplotlib networkx nltk inltk indic-nlp-lib

# %%
pip show pandas numpy matplotlib networkx nltk inltk indic-nlp-lib fastai

# %%
# !pip install indicnlp
# Out:
# Collecting indicnlp
#   Downloading indicnlp-0.0.1-py3-none-any.whl.metadata (516 bytes)
# Downloading indicnlp-0.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: indicnlp
# Successfully installed indicnlp-0.0.1

# %%
pip install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.10/site-packages (from indic-nlp-library) (0.2.4)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from indic-nlp-library) (2.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->indic-nlp-library) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->indic-nlp-library) (2023.4)
# Collecting sphinx>=1.2.0 (from sphinx-argparse->indic-nlp-library)
#   Downloading sphinx-7.3.7-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.16.0)
# Collecting sphinxcontrib-applehelp (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl.metadata (2.4 kB)
# Collecting sphinxcontrib-qthelp (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: Pygments>=2.14 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.17.2)
# Requirement already satisfied: docutils<0.22,>=0.18.1 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.20.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.14.0)
# Collecting alabaster~=0.7.14 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading alabaster-0.7.16-py3-none-any.whl.metadata (2.9 kB)
# Collecting imagesize>=1.3 (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests>=2.25.0 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging>=21.0 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (21.3)
# Requirement already satisfied: tomli>=2 in /opt/conda/lib/python3.10/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2>=3.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2024.2.2)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.1 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Downloading sphinx-7.3.7-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 35.3 MB/s eta 0:00:0000:0100:01
# Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 5.8 MB/s eta 0:00:00
# Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 5.5 MB/s eta 0:00:00
# Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 7.4 MB/s eta 0:00:00
# Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 4.9 MB/s eta 0:00:00
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: morfessor, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, imagesize, alabaster, sphinx, sphinx-argparse, indic-nlp-library
# Successfully installed alabaster-0.7.16 imagesize-1.4.1 indic-nlp-library-0.92 morfessor-2.0.6 sphinx-7.3.7 sphinx-argparse-0.4.0 sphinxcontrib-applehelp-1.0.8 sphinxcontrib-devhelp-1.0.6 sphinxcontrib-htmlhelp-2.0.5 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.7 sphinxcontrib-serializinghtml-1.1.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from nltk.cluster.util import cosine_distance
import string
import math
import operator
import inltk
# from inltk.inltk import setup
import nltk
# from nltk.tokenize import SpaceTokenizer
import re
from matplotlib.font_manager import FontProperties
hindi_font=FontProperties(fname = 'Nirmala-UI.ttf')
import indicnlp
from indicnlp.tokenize import sentence_tokenize
# from inltk.inltk import get_sentence_similarity
# from inltk.inltk import get_sentence_similarity

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df=pd.read_csv('/kaggle/input/hindi-data/CNN_3000 translated_Hindi_IndicTrans_main.csv',nrows=3000,delimiter=',')
pd.set_option('display.max_colwidth',None)

# %%
stopwords=pd.read_csv('/kaggle/input/stop-wrods/StopwordsHindi.csv')
stopwords=list(stopwords['stopwords'])
stopwords.extend(['में','के','है','से'])

# %%
df.dropna(inplace=True)

# %%
df=df.head(500)

# %%
df.shape
# Out:
# (3000, 3)

# %%
def remove_redundant_sentences(sentences):
    cleaned=[]
    for s in sentences:
        if s in cleaned or s.strip()=='':
            continue
        else:
            cleaned.append(s)
    return cleaned

def clean_corpus(corpus):
    corpus=corpus.replace('।','.')
    corpus=corpus.replace('\xa0','')
    corpus=corpus.replace('\n','')
    corpus=corpus.replace('\r','')
    return corpus

def get_clean_sentences(doc):
    cleaned_doc=clean_corpus(doc)
    sentences=cleaned_doc.split('.')
    sentences=remove_redundant_sentences(sentences)
    return sentences

# %%
patternEnglish = re.compile(r'[[A-Z]|[a-z]]*')
patternNumeric = re.compile(r'.*[0-9]+')
patternBraces=re.compile(r'\[(.*?)\]|\{(.*?)\}|\((.*?)\)')
patternUrl=re.compile(r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))")
# Out:
# /tmp/ipykernel_35/850458489.py:1: FutureWarning: Possible nested set at position 1
#   patternEnglish = re.compile(r'[[A-Z]|[a-z]]*')

# %% [markdown]
# Method I : Rule based extractive summarization

# %%
def titlewordsScore(sentence,heading_titlewords):
    titlewords_sent=SpaceTokenizer().tokenize(sentence)
    titlewords_count=len(heading_titlewords)
    titlewords_sent=[word for word in titlewords_sent if word in heading_titlewords]
    s1_score=len(titlewords_sent)/titlewords_count
    return (s1_score)

# %%
def get_len_all_sentences(sentences):
    len_of_all_sent=[len(SpaceTokenizer().tokenize(sentence)) for sentence in sentences]
    max_length=np.max(len_of_all_sent)
    return max_length, len_of_all_sent

# %%
def searchEnglishWords(sentence):
    words=SpaceTokenizer().tokenize(sentence.strip())
    words=list(filter(None,words))
    english_words=[word for word in words if patternEnglish.match(word) !=None]
    return len(english_words)/len(words)

# %%
def positionScore(total_len):
    mid=(total_len/2)
    positions=(np.arange(total_len,mid,-1)/total_len).tolist()
    if(total_len%2==0):
        positions.extend((np.arange(mid+1,total_len+1,1)/total_len).tolist())
    else:
        positions.extend(np.arange(mid,total_len+1,1).tolist())
    return positions

# %%
def numericScore(sentence):
    words=SpaceTokenizer().tokenize(sentence)
    numbers=[1 for word in words if re.match(patternNumeric,word)]
    return np.sum(numbers)/len(words)

def bracesScore(sentence):
    t=re.findall(patternBraces,sentence)
    words=SpaceTokenizer().tokenize(sentence)
    insideTerms=()
    for term in t:
        insideTerms+=term
    insideTerms=[term for term in insideTerms if term !='']
    return (len(words)-len(insideTerms))/len(words)

# %%
def url_email_score(sentence):
    words=SpaceTokenizer().tokenize(sentence.strip())
    words=list(filter(None, words))
    urls=[word for word in words if patternUrl.match(word)!=None]
    return len(urls)/len(words)

# %%
def generate_summary_rule_based(clean_sentences,compression_ratio):
    score_table=pd.DataFrame(clean_sentences)
    score_table.columns=['sentence']

    headlinetokens=SpaceTokenizer().tokenize(sample['highlights_hindi'])
    heading_titlewords=[ word for word in  headlinetokens if word!= '' and word not in stopwords]
    score_table['S1']=[titlewordsScore(sentence,heading_titlewords) for sentence in clean_sentences]
    max_length,len_of_all_sent=get_len_all_sentences(clean_sentences)
    score_table['S2']=[x/max_length for x in len_of_all_sent]
    score_table['S3']=[searchEnglishWords(sentence) for sentence in clean_sentences]
    score_table['S4']=[numericScore(sentence) for sentence in clean_sentences]
    score_table['S5']=[bracesScore(sentence) for sentence in clean_sentences]
    score_table['S7']=[url_email_score(sentence) for sentence in clean_sentences]
    #score_table['S8']=positionScore(len(clean_sentences))
    score_table['Total']=score_table['S1']+score_table['S2']+score_table['S3']+score_table['S4']+score_table['S5']+score_table['S7']
    summary_sent_count=round(compression_ratio*len(clean_sentences))
    summary_sent=list(score_table.sort_values('Total',ascending=False).iloc[0:summary_sent_count]['sentence'])
    summary=""
    for sentence in summary_sent:
        summary+=sentence.strip()+"| "
    return summary

# %%
from nltk.tokenize import SpaceTokenizer

# %%
sample=df.iloc[1]
clean_sentences=get_clean_sentences(sample['article_hindi'])
summary_rule_based=generate_summary_rule_based(clean_sentences,0.4)

print('Summary obtained from rule based strategy: ',summary_rule_based,'\n')
# Out:
# Summary obtained from rule based strategy:  के संवाददाताओं ने ड्रग्स के आरोपों या एक अधिकारी पर हमला करने के आरोपों का सामना करते हुए समाचारों को कवर करने और घटनाओं के पीछे की कहानियों का विश्लेषण करने में अपने अनुभवों को साझा किया| एक कैदी को "भूल गए फर्श" पर रखा जाता है, जहां कई मानसिक रूप से बीमार कैदियों को मुकदमे से पहले मियामी में रखा जाता है| यहाँ, सबसे गंभीर मानसिक बीमारियों वाले कैदियों को तब तक जेल में रखा जाता है जब तक कि वे अदालत में पेश होने के लिए तैयार नहीं होते हैं| यहां तक कि सोलेदाद ओ' ब्रायन ने अक्सर उपयोगकर्ताओं को एक जेल के अंदर ले जाते हैं, जहां कई कैदी मानसिक रूप से बीमार होते हैं|

# %%
summary=[]
for i in range(len(df)):
    clean_sentences=get_clean_sentences(sample['article_hindi'])
    summary_rule_based=generate_summary_rule_based(clean_sentences,0.4)
    summary.append(summary_rule_based)

# %%
summary[0]
# Out:
# 'के संवाददाताओं ने ड्रग्स के आरोपों या एक अधिकारी पर हमला करने के आरोपों का सामना करते हुए समाचारों को कवर करने और घटनाओं के पीछे की कहानियों का विश्लेषण करने में अपने अनुभवों को साझा किया| एक कैदी को "भूल गए फर्श" पर रखा जाता है, जहां कई मानसिक रूप से बीमार कैदियों को मुकदमे से पहले मियामी में रखा जाता है| यहाँ, सबसे गंभीर मानसिक बीमारियों वाले कैदियों को तब तक जेल में रखा जाता है जब तक कि वे अदालत में पेश होने के लिए तैयार नहीं होते हैं| यहां तक कि सोलेदाद ओ\' ब्रायन ने अक्सर उपयोगकर्ताओं को एक जेल के अंदर ले जाते हैं, जहां कई कैदी मानसिक रूप से बीमार होते हैं| '

# %%
import pandas as pd

# Assuming df contains your data with 'article_hindi' column and get_clean_sentences(), generate_summary_rule_based() functions are defined

# Create an empty list to store the data and summaries
data_with_summaries = []

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    # Get clean sentences from the article text in the current row
    clean_sentences = get_clean_sentences(row['article_hindi'])
    
    # Generate summary based on clean sentences
    summary_rule_based = generate_summary_rule_based(clean_sentences, 0.4)
    
    # Append the original text and generated summary to the list
    data_with_summaries.append({
        'Original_Text': row['article_hindi'],
        'Generated_Summary': ' '.join(summary_rule_based)  # Convert summary list to a single string
    })

# Create a DataFrame from the list

df_with_summaries = pd.DataFrame(data_with_summaries)

# Specify the output CSV file path
output_csv_path = 'data_with_generated_summaries2.csv'

# Save the DataFrame to a CSV file with UTF-8 encoding
df_with_summaries.to_csv(output_csv_path, index=False, encoding='utf-8')

print(f'Data with generated summaries saved to {output_csv_path}')
# Out:
# Data with generated summaries saved to data_with_generated_summaries2.csv

# %%
data_with_summaries = []

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    # Get clean sentences from the article text in the current row
    clean_sentences = get_clean_sentences(row['article_hindi'])
    
    # Generate summary based on clean sentences
    summary_rule_based = generate_summary_rule_based(clean_sentences, 0.4)
    
    # Convert summary list to a single string with appropriate formatting
#     generated_summary_str = '\n'.join(summary_rule_based)  # Separate summaries by new lines
    
    # Append the original text and formatted generated summary to the list
    data_with_summaries.append({
        'Original_Text': row['article_hindi'],
        'Generated_Summary': summary_rule_based
    })

# %%
# Specify the output CSV file path
df_with_summaries = pd.DataFrame(data_with_summaries)
output_csv_path = 'data_with_generated_summaries3.csv'

# Save the DataFrame to a CSV file with UTF-8 encoding
df_with_summaries.to_csv(output_csv_path, index=False, encoding='utf-8')

print(f'Data with generated summaries saved to {output_csv_path}')
# Out:
# Data with generated summaries saved to data_with_generated_summaries3.csv

# %% [markdown]
# Text Summarization using TF-IDF scores of sentences¶

# %%
def calc_term_frequency_sentence_wise(sentences):
    freq_matrix={}
    for sentence in sentences:
        words=SpaceTokenizer().tokenize(sentence)
        sent_freq_table={}
        for word in words:
            if word in stopwords:
                continue
            if word in sent_freq_table:
                sent_freq_table[word]+=1
            else:
                sent_freq_table[word]=1
        freq_matrix[sentence[:15]]=sent_freq_table
    return freq_matrix
        
def calc_tf_matrix(freq_matrix):
    for sentence,sent_freq_table in freq_matrix.items():
        tf_sent={}
        sent_len=len(sent_freq_table)
        for word in sent_freq_table:
            sent_freq_table[word]/=sent_len
    return freq_matrix

def calc_sentence_frequency(freq_matrix):
    sent_freq={}
    for sentence,freq_matrix_sent in freq_matrix.items():
        for word,count in freq_matrix_sent.items():
            if word in sent_freq:
                sent_freq[word]+=1
            else:
                sent_freq[word]=1
    return sent_freq

def calc_idf_score(total_sentences,sent_freq,freq_matrix):
    idf={}
    for sentence,freq_matrix_sent in freq_matrix.items():
        idf_sent={}
        for word in freq_matrix_sent:
            idf_sent[word]=math.log10(total_sentences / float(sent_freq[word]))
        idf[sentence]=idf_sent
    return idf
    
def calc_tf_idf_score(tf,idf):
    tf_idf={}
    for (sentence1,tf_sent),(sentence2,idf_sent) in zip(tf.items(),idf.items()):
        tf_idf_sent={}
        for (word1,tf_score),(word2,idf_score) in zip(tf_sent.items(),idf_sent.items()):
            tf_idf_sent[word1]=tf_score*idf_score
        tf_idf[sentence1]=tf_idf_sent
    return tf_idf

def calc_tf_idf_score_sentence_wise(tf_idf_matrix):
    tf_idf={}
    for sentence,tf_idf_sent in tf_idf_matrix.items():
        tf_idf_sentence=0
        for word,tf_idf_score in tf_idf_sent.items():
            tf_idf_sentence+=tf_idf_score
        tf_idf[sentence]=tf_idf_sentence
    return tf_idf
def get_tf_idf(sentences):
    sent_freq_matrix=calc_term_frequency_sentence_wise(sentences)
    freq_matrix=calc_tf_matrix(sent_freq_matrix)
    total_sentences=len(sentences)
    sent_freq=calc_sentence_frequency(freq_matrix)
    idf=calc_idf_score(total_sentences,sent_freq,freq_matrix)
    tf_idf_matrix=calc_tf_idf_score(freq_matrix,idf)
    tf_idf=calc_tf_idf_score_sentence_wise(tf_idf_matrix)
    return tf_idf

def summarise_tf_idf_sentence_weighting(sentences):
    tf_idf=get_tf_idf(sentences)
    sentences=remove_redundant_sentences(sentences)
    avg_tf_idf_score=average_sentence_value(tf_idf)
    tf_idf_summary,sent_count=generate_summary(avg_tf_idf_score,sentences,tf_idf,15)
    return tf_idf_summary

# %%
import pandas as pd

# Assuming df contains your data with 'article_hindi' column and get_clean_sentences(), summarise_tf_idf_sentence_weighting() functions are defined

# Create an empty list to store the cleaned sentences and TF-IDF summaries
clean = []
for i in df['article_hindi']:
    clean.append(get_clean_sentences(i))

tf_idf_summary = []
for j in clean:
    tf_idf_summary.append(summarise_tf_idf_sentence_weighting(j))

# Create a DataFrame with 'article_hindi' and 'tf_idf_summary' columns
df_summary = pd.DataFrame({'article_hindi': df['article_hindi'], 'tf_idf_summary': tf_idf_summary})

# Specify the output CSV file path
output_csv_path = 'article_with_summary.csv'

# Save the DataFrame to a CSV file
df_summary.to_csv(output_csv_path, index=False, encoding='utf-8')

print(f'Data with generated summaries saved to {output_csv_path}')
# Out:
# Data with generated summaries saved to article_with_summary.csv
